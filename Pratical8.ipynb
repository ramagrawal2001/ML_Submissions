# %% [markdown]
# Importing modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
df = pd.read_csv("heart-Copy1.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
dummy_features = pd.get_dummies(df['ChestPainType'],drop_first=True)

# %%
dummy_features
# Out:
#      ATA  NAP  TA
# 0      1    0   0
# 1      0    1   0
# 2      1    0   0
# 3      0    0   0
# 4      0    1   0
# ..   ...  ...  ..
# 913    0    0   1
# 914    0    0   0
# 915    0    0   0
# 916    1    0   0
# 917    0    1   0
#
# [918 rows x 3 columns]

# %%
# Creating a dummy variable for some of the categorical variables and dropping the first one.
dummy1 = pd.get_dummies(df[['Sex', 'ChestPainType','RestingECG','ExerciseAngina','ST_Slope']], drop_first=True)

# Adding the results to the master dataframe
final_data = pd.concat([df, dummy1], axis=1)

# %%
# Adding the results to the master dataframe
final_data = pd.concat([df, dummy1], axis=1)

# %%
final_data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak  ... HeartDisease  Sex_M  ChestPainType_ATA  \
# 0              N      0.0  ...            0      1                  1
# 1              N      1.0  ...            1      0                  0
# 2              N      0.0  ...            0      1                  1
# 3              Y      1.5  ...            1      0                  0
# 4              N      0.0  ...            0      1                  0
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  RestingECG_ST  \
# ...

# %%
final_data = final_data.drop(['Sex', 'ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],1)

# %%
final_data.shape
# Out:
# (918, 16)

# %%
final_data.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...

# %% [markdown]
# Assigning values to input output vector

# %%
x_data = final_data.drop('HeartDisease',1)
y_data = final_data['HeartDisease']

# %%
X = x_data.to_numpy()
y = y_data.to_numpy()

# %% [markdown]
# linear descriminant analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()

lda.fit(X, y)
yp= lda.predict(X)

# %%
lda.decision_function(X)
# Out:
# array([-4.62410312, -1.07379597, -4.23273202,  2.69694306, -3.37215443,
#        -4.74510053, -5.77829361, -3.80884873,  3.87292834, -5.65780369,
#        -5.4789103 ,  2.58918854, -4.10615314,  3.69815988, -5.37873112,
#        -1.39821707,  1.66547078, -5.63477578,  2.58354895,  0.40420941,
#        -5.11300963,  0.14093583, -5.49333812,  1.88453154, -3.90439115,
#        -4.20459458,  4.73644814, -4.05480384, -6.50457884, -3.76355706,
#        -1.47385948, -3.18429183,  3.11493586,  3.046716  , -5.43467822,
#        -4.54941602,  5.49586353, -5.80182165, -4.06651577,  2.28621854,
#        -5.26878376, -0.42878149, -4.5640842 , -4.04628823,  3.94056078,
#         1.42435755, -2.03108628, -4.04408363, -0.88996142,  1.25174517,
#         4.2941509 ,  2.98164378, -2.64780862, -5.77989559,  2.73587262,
#        -5.38171706,  3.25827393,  0.02010054, -1.62714905,  3.44238305,
#        -4.34969612, -5.72285508, -1.679575  ,  3.47688828, -5.38873919,
# ...

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix = confusion_matrix(y, yp)
print(confusion_matrix)
# Out:
# [[343  67]
#  [ 52 456]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y, yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85       410
#            1       0.87      0.90      0.88       508
#
#     accuracy                           0.87       918
#    macro avg       0.87      0.87      0.87       918
# weighted avg       0.87      0.87      0.87       918
